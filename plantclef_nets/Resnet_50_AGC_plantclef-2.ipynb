# %% [markdown]
# # Data download and preparation

# %%
#@title Print TF version and GPU stats
import tensorflow as tf
print('TensorFlow version:', tf.__version__)

device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
   raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name), '', sep='\n')
# !nvidia-smi
# Out:
# TensorFlow version: 2.7.0
# Found GPU at: /device:GPU:0
#
# Tue Jan 25 14:31:59 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.46       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   64C    P0    29W /  70W |    264MiB / 15109MiB |      1%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
#@title Dataset Downloader
import requests, os, zipfile
import numpy as np

def download_file_from_google_drive(id, destination):
    URL = "https://docs.google.com/uc?export=download"
    session = requests.Session()
    response = session.get(URL, params = { 'id' : id }, stream = True)
    token = get_confirm_token(response)
    if token:
        params = { 'id' : id, 'confirm' : token }
        response = session.get(URL, params = params, stream = True)
    save_response_content(response, destination)    

def get_confirm_token(response):
    for key, value in response.cookies.items():
        if key.startswith('download_warning'):
            return value
    return None

def save_response_content(response, destination):
    CHUNK_SIZE = 32768
    with open(destination, "wb") as f:
        for chunk in response.iter_content(CHUNK_SIZE):
            if chunk: # filter out keep-alive new chunks
                f.write(chunk)
                
def unzip(file, destination=None):
  if not destination or not os.path.isdir(destination):
    destination = os.path.dirname(file)
  print('unzipping to ',destination)
  zip_ref = zipfile.ZipFile(file, 'r')
  zip_ref.extractall(destination)
  zip_ref.close()
    
download_file_from_google_drive('1UC77Z-Zon-NV9G_CxKbI1weFyd9relb7', '/plantclef_data.zip') # flowers10
unzip('/plantclef_data.zip', '/tmp')

train_dir = '/tmp/plantclef_data/train'
val_dir = '/tmp/plantclef_data/test'
# Out:
# unzipping to  /tmp

# %%
#@title Prepare Data Generators
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator

batch_size = 512

# All images will be rescaled by 1./255
train_datagen = ImageDataGenerator(rescale=1./255,
                                   rotation_range=20,
                                   width_shift_range=0.1,
                                   height_shift_range=0.1,
                                   zoom_range=0.4,
                                   brightness_range=(.5, 1.5),
                                   horizontal_flip=True,
                                   vertical_flip=True,
                                   fill_mode='nearest')
val_datagen = ImageDataGenerator(rescale=1./255)

# Flow training images in batches using train_datagen generator
train_generator = train_datagen.flow_from_directory(
                    train_dir,
                    target_size=(64,64),
                    batch_size=batch_size,
                    class_mode='categorical',
                    shuffle=True,
                    seed=42)

num_classes = train_generator.num_classes

# Flow test images in batches using val_datagen generator
val_generator = val_datagen.flow_from_directory(
                    val_dir,
                    target_size=(64,64),
                    batch_size=batch_size,
                    class_mode='categorical',
                    shuffle=False)

train_steps = len(train_generator)
val_steps = len(val_generator)
# Out:
# Found 20359 images belonging to 241 classes.
# Found 5092 images belonging to 241 classes.

# %%
#@title `plot_history()` definition
from matplotlib import pyplot as plt

def plot_history(history):
  fig, (ax1, ax2) = plt.subplots(2,1, sharex=True, dpi=150)
  ax1.plot(history.history['loss'], label='training')
  ax1.plot(history.history['val_loss'], label='validation')
  ax1.set_ylabel('Cross-Entropy Loss')
  ax1.set_yscale('log')
  if history.history.__contains__('lr'):
    ax1b = ax1.twinx()
    ax1b.plot(history.history['lr'], 'g-', linewidth=1)
    ax1b.set_yscale('log')
    ax1b.set_ylabel('Learning Rate', color='g')

  ax2.plot(history.history['accuracy'], label='training')
  ax2.plot(history.history['val_accuracy'], label='validation')
  ax2.set_ylabel('Accuracy')
  ax2.set_xlabel('Epochs')
  ax2.legend()
  plt.show()

# %% [markdown]
# # Defining AGC model

# %% [markdown]
# For the implementation of the adaptive gradient clipping we use this following github [repo](https://github.com/sayakpaul/Adaptive-Gradient-Clipping/blob/main/agc.py)

# %%
import tensorflow as tf

def compute_norm(x, axis, keepdims):
    return tf.math.reduce_sum(x ** 2, axis=axis, keepdims=keepdims) ** 0.5

def unitwise_norm(x):
    if len(x.get_shape()) <= 1:  # Scalars and vectors
        axis = None
        keepdims = False
    elif len(x.get_shape()) in [2, 3]:  # Linear layers of shape IO or multihead linear
        axis = 0
        keepdims = True
    elif len(x.get_shape()) == 4:  # Conv kernels of shape HWIO
        axis = [0, 1, 2,]
        keepdims = True
    else:
        raise ValueError(f"Got a parameter with shape not in [1, 2, 4]! {x}")
    return compute_norm(x, axis, keepdims)


def adaptive_clip_grad(parameters, gradients, clip_factor=0.01,
                       eps=1e-3):
    new_grads = []
    for (params, grads) in zip(parameters, gradients):
        p_norm = unitwise_norm(params)
        max_norm = tf.math.maximum(p_norm, eps) * clip_factor
        grad_norm = unitwise_norm(grads)
        clipped_grad = grads * (max_norm / tf.math.maximum(grad_norm, 1e-6))
        new_grad = tf.where(grad_norm < max_norm, grads, clipped_grad)
        new_grads.append(new_grad)
    return new_grads

# %% [markdown]
# # Resnet 50 architecture without batchnorm

# %%
"""ResNet50 model for Keras.
# Reference:
- [Deep Residual Learning for Image Recognition](
    https://arxiv.org/abs/1512.03385) (CVPR 2016 Best Paper Award)
Adapted from code contributed by BigMoyan.
"""

import os
import warnings
from tensorflow.keras import layers, models, backend, utils


def identity_block(input_tensor, kernel_size, filters, stage, block):
    """The identity block is the block that has no conv layer at shortcut.
    # Arguments
        input_tensor: input tensor
        kernel_size: default 3, the kernel size of
            middle conv layer at main path
        filters: list of integers, the filters of 3 conv layer at main path
        stage: integer, current stage label, used for generating layer names
        block: 'a','b'..., current block label, used for generating layer names
    # Returns
        Output tensor for the block.
    """
    filters1, filters2, filters3 = filters
    # if backend.image_data_format() == 'channels_last':
    #     bn_axis = 3
    # else:
    #     bn_axis = 1
    conv_name_base = 'res' + str(stage) + block + '_branch'
    #bn_name_base = 'bn' + str(stage) + block + '_branch'

    x = layers.Conv2D(filters1, (1, 1),
                      kernel_initializer='he_normal',
                      name=conv_name_base + '2a')(input_tensor)
    # x = layers.BatchNormalization(axis=bn_axis, name=bn_name_base + '2a')(x)
    x = layers.Activation('relu')(x)

    x = layers.Conv2D(filters2, kernel_size,
                      padding='same',
                      kernel_initializer='he_normal',
                      name=conv_name_base + '2b')(x)
    # x = layers.BatchNormalization(axis=bn_axis, name=bn_name_base + '2b')(x)
    x = layers.Activation('relu')(x)

    x = layers.Conv2D(filters3, (1, 1),
                      kernel_initializer='he_normal',
                      name=conv_name_base + '2c')(x)
    # x = layers.BatchNormalization(axis=bn_axis, name=bn_name_base + '2c')(x)

    x = layers.add([x, input_tensor])
    x = layers.Activation('relu')(x)
    return x


def conv_block(input_tensor,
               kernel_size,
               filters,
               stage,
               block,
               strides=(2, 2)):
    """A block that has a conv layer at shortcut.
    # Arguments
        input_tensor: input tensor
        kernel_size: default 3, the kernel size of
            middle conv layer at main path
        filters: list of integers, the filters of 3 conv layer at main path
        stage: integer, current stage label, used for generating layer names
        block: 'a','b'..., current block label, used for generating layer names
        strides: Strides for the first conv layer in the block.
    # Returns
        Output tensor for the block.
    Note that from stage 3,
    the first conv layer at main path is with strides=(2, 2)
    And the shortcut should have strides=(2, 2) as well
    """
    filters1, filters2, filters3 = filters
    # if backend.image_data_format() == 'channels_last':
    #     bn_axis = 3
    # else:
    #     bn_axis = 1
    conv_name_base = 'res' + str(stage) + block + '_branch'
    # bn_name_base = 'bn' + str(stage) + block + '_branch'

    x = layers.Conv2D(filters1, (1, 1), strides=strides,
                      kernel_initializer='he_normal',
                      name=conv_name_base + '2a')(input_tensor)
    #x = layers.BatchNormalization(axis=bn_axis, name=bn_name_base + '2a')(x)
    x = layers.Activation('relu')(x)

    x = layers.Conv2D(filters2, kernel_size, padding='same',
                      kernel_initializer='he_normal',
                      name=conv_name_base + '2b')(x)
    #x = layers.BatchNormalization(axis=bn_axis, name=bn_name_base + '2b')(x)
    x = layers.Activation('relu')(x)

    x = layers.Conv2D(filters3, (1, 1),
                      kernel_initializer='he_normal',
                      name=conv_name_base + '2c')(x)
    #x = layers.BatchNormalization(axis=bn_axis, name=bn_name_base + '2c')(x)

    shortcut = layers.Conv2D(filters3, (1, 1), strides=strides,
                             kernel_initializer='he_normal',
                             name=conv_name_base + '1')(input_tensor)
    #shortcut = layers.BatchNormalization(axis=bn_axis, name=bn_name_base + '1')(shortcut)

    x = layers.add([x, shortcut])
    x = layers.Activation('relu')(x)
    return x


def ResNet50(input_shape=None,
             classes=241):
    """Instantiates the ResNet50 architecture.
    # Arguments
        include_top: whether to include the fully-connected
            layer at the top of the network.
        weights: one of `None` (random initialization),
              'imagenet' (pre-training on ImageNet),
              or the path to the weights file to be loaded.
        input_tensor: optional Keras tensor (i.e. output of `layers.Input()`)
            to use as image input for the model.
        input_shape: optional shape tuple, only to be specified
            if `include_top` is False (otherwise the input shape
            has to be `(224, 224, 3)` (with `channels_last` data format)
            or `(3, 224, 224)` (with `channels_first` data format).
            It should have exactly 3 inputs channels,
            and width and height should be no smaller than 32.
            E.g. `(200, 200, 3)` would be one valid value.
        pooling: Optional pooling mode for feature extraction
            when `include_top` is `False`.
            - `None` means that the output of the model will be
                the 4D tensor output of the
                last convolutional block.
            - `avg` means that global average pooling
                will be applied to the output of the
                last convolutional block, and thus
                the output of the model will be a 2D tensor.
            - `max` means that global max pooling will
                be applied.
        classes: optional number of classes to classify images
            into, only to be specified if `include_top` is True, and
            if no `weights` argument is specified.
    # Returns
        A Keras model instance.
    """
    
    img_input = layers.Input(shape=input_shape)
    # if backend.image_data_format() == 'channels_last':
    #     bn_axis = 3
    # else:
    #     bn_axis = 1

    x = layers.ZeroPadding2D(padding=(3, 3), name='conv1_pad')(img_input)
    x = layers.Conv2D(64, (7, 7),
                      strides=(2, 2),
                      padding='valid',
                      kernel_initializer='he_normal',
                      name='conv1')(x)
    #x = layers.BatchNormalization(axis=bn_axis, name='bn_conv1')(x)
    x = layers.Activation('relu')(x)
    x = layers.ZeroPadding2D(padding=(1, 1), name='pool1_pad')(x)
    x = layers.MaxPooling2D((3, 3), strides=(2, 2))(x)

    x = conv_block(x, 3, [64, 64, 256], stage=2, block='a', strides=(1, 1))
    x = identity_block(x, 3, [64, 64, 256], stage=2, block='b')
    x = identity_block(x, 3, [64, 64, 256], stage=2, block='c')

    x = conv_block(x, 3, [128, 128, 512], stage=3, block='a')
    x = identity_block(x, 3, [128, 128, 512], stage=3, block='b')
    x = identity_block(x, 3, [128, 128, 512], stage=3, block='c')
    x = identity_block(x, 3, [128, 128, 512], stage=3, block='d')

    x = conv_block(x, 3, [256, 256, 1024], stage=4, block='a')
    x = identity_block(x, 3, [256, 256, 1024], stage=4, block='b')
    x = identity_block(x, 3, [256, 256, 1024], stage=4, block='c')
    x = identity_block(x, 3, [256, 256, 1024], stage=4, block='d')
    x = identity_block(x, 3, [256, 256, 1024], stage=4, block='e')
    x = identity_block(x, 3, [256, 256, 1024], stage=4, block='f')

    x = conv_block(x, 3, [512, 512, 2048], stage=5, block='a')
    x = identity_block(x, 3, [512, 512, 2048], stage=5, block='b')
    x = identity_block(x, 3, [512, 512, 2048], stage=5, block='c')

    
    x = layers.GlobalAveragePooling2D(name='avg_pool')(x)
    x = layers.Dense(classes, activation='softmax', name='fc10')(x)
    
    model = Model(img_input, x)

    return model

# %%
import tensorflow as tf
from tensorflow.keras import Model

class ResNet50_AGC_Model(Model):

  def __init__(self, inputshape, name, threshold=1e-3):
        super(ResNet50_AGC_Model, self).__init__()
        self.threshold = threshold
        self.resnet = ResNet50(input_shape=inputshape, classes=num_classes)

  #this bit of code is from keras API
  def train_step(self, data):
    # Unpack the data
    images, y = data

    with tf.GradientTape() as tape:
        y_pred = self.resnet(images)  # Forward pass
        # Compute the loss value
        loss = self.compiled_loss(y, y_pred, regularization_losses=self.losses)

    # Compute gradients
    trainable_vars = self.resnet.trainable_variables
    gradients = tape.gradient(loss, trainable_vars)
    # Update gradients
    updated_grad = adaptive_clip_grad(trainable_vars, gradients, self.threshold)
    # Update weights
    self.optimizer.apply_gradients(zip(updated_grad, trainable_vars))
    # Update metrics (includes the metric that tracks the loss)
    self.compiled_metrics.update_state(y, y_pred)
    # Return a dict mapping metric names to current value
    return {m.name: m.result() for m in self.metrics}

  def test_step(self, data):
    images, labels = data
    predictions = self.resnet(images, training=False)
    loss = self.compiled_loss(labels, predictions)
    self.compiled_metrics.update_state(labels, predictions)
    return {m.name: m.result() for m in self.metrics}

  def call(self, inputs):
    return self.resnet(inputs)

# %%
from tensorflow.keras.optimizers import Adam
clipping_factor = 0.08 # As described in the base paper of this study
resnet50 = ResNet50_AGC_Model((64,64,3), threshold=0.08, name='resnet50_agc')

resnet50.compile(loss='categorical_crossentropy',
            optimizer=Adam(learning_rate=1e-3),
            metrics=['accuracy'])

# %%
history = resnet50.fit(train_generator,
                        steps_per_epoch=train_steps,# trained with 512
                        epochs=100,
                        validation_data=val_generator,
                        validation_steps=val_steps
                       )
plot_history(history)
# Out:
# Epoch 1/100
# 40/40 [==============================] - 61s 1s/step - loss: 31.3546 - accuracy: 0.0205 - val_loss: 5.2017 - val_accuracy: 0.0190
# Epoch 2/100
# 40/40 [==============================] - 39s 981ms/step - loss: 4.7808 - accuracy: 0.0428 - val_loss: 5.0692 - val_accuracy: 0.0247
# Epoch 3/100
# 40/40 [==============================] - 39s 976ms/step - loss: 4.4944 - accuracy: 0.0668 - val_loss: 4.9231 - val_accuracy: 0.0365
# Epoch 4/100
# 40/40 [==============================] - 39s 976ms/step - loss: 4.3543 - accuracy: 0.0840 - val_loss: 5.0264 - val_accuracy: 0.0287
# Epoch 5/100
# 40/40 [==============================] - 39s 977ms/step - loss: 4.2320 - accuracy: 0.0958 - val_loss: 4.8901 - val_accuracy: 0.0397
# Epoch 6/100
# 40/40 [==============================] - 39s 975ms/step - loss: 4.0789 - accuracy: 0.1198 - val_loss: 4.7977 - val_accuracy: 0.0377
# Epoch 7/100
# 40/40 [==============================] - 39s 973ms/step - loss: 3.9176 - accuracy: 0.1421 - val_loss: 4.6822 - val_accuracy: 0.0652
# Epoch 8/100
# 40/40 [==============================] - 39s 978ms/step - loss: 3.7625 - accuracy: 0.1660 - val_loss: 4.8225 - val_accuracy: 0.0544
# Epoch 9/100
# 40/40 [==============================] - 39s 973ms/step - loss: 3.6370 - accuracy: 0.1795 - val_loss: 4.7960 - val_accuracy: 0.0613
# Epoch 10/100
# 40/40 [==============================] - 39s 980ms/step - loss: 3.5258 - accuracy: 0.1994 - val_loss: 4.8054 - val_accuracy: 0.0617
# Epoch 11/100
# 40/40 [==============================] - 39s 971ms/step - loss: 3.4563 - accuracy: 0.2061 - val_loss: 4.7338 - val_accuracy: 0.0766
# Epoch 12/100
# 40/40 [==============================] - 39s 973ms/step - loss: 3.3142 - accuracy: 0.2313 - val_loss: 4.7177 - val_accuracy: 0.0896
# Epoch 13/100
# 40/40 [==============================] - 39s 974ms/step - loss: 3.1396 - accuracy: 0.2618 - val_loss: 4.6992 - val_accuracy: 0.0819
# Epoch 14/100
# 40/40 [==============================] - 39s 979ms/step - loss: 3.0746 - accuracy: 0.2749 - val_loss: 4.6792 - val_accuracy: 0.0956
# Epoch 15/100
# 40/40 [==============================] - 39s 978ms/step - loss: 3.0030 - accuracy: 0.2873 - val_loss: 4.7991 - val_accuracy: 0.0882
# Epoch 16/100
# 40/40 [==============================] - 39s 975ms/step - loss: 2.9011 - accuracy: 0.3032 - val_loss: 4.8195 - val_accuracy: 0.0954
# Epoch 17/100
# 40/40 [==============================] - 39s 972ms/step - loss: 2.8632 - accuracy: 0.3084 - val_loss: 4.8478 - val_accuracy: 0.0970
# Epoch 18/100
# 40/40 [==============================] - 39s 976ms/step - loss: 2.7762 - accuracy: 0.3223 - val_loss: 4.9288 - val_accuracy: 0.0899
# Epoch 19/100
# 40/40 [==============================] - 39s 973ms/step - loss: 2.6798 - accuracy: 0.3394 - val_loss: 5.0442 - val_accuracy: 0.0919
# Epoch 20/100
# 40/40 [==============================] - 39s 972ms/step - loss: 2.5701 - accuracy: 0.3610 - val_loss: 5.2051 - val_accuracy: 0.0964
# Epoch 21/100
# 40/40 [==============================] - 39s 975ms/step - loss: 2.4950 - accuracy: 0.3732 - val_loss: 5.1243 - val_accuracy: 0.1057
# Epoch 22/100
# 40/40 [==============================] - 39s 970ms/step - loss: 2.3981 - accuracy: 0.3942 - val_loss: 5.3049 - val_accuracy: 0.1021
# Epoch 23/100
# 40/40 [==============================] - 39s 973ms/step - loss: 2.3428 - accuracy: 0.4001 - val_loss: 5.1566 - val_accuracy: 0.0998
# Epoch 24/100
# 40/40 [==============================] - 39s 971ms/step - loss: 2.2364 - accuracy: 0.4262 - val_loss: 5.4817 - val_accuracy: 0.1066
# Epoch 25/100
# 40/40 [==============================] - 39s 976ms/step - loss: 2.1859 - accuracy: 0.4378 - val_loss: 5.5303 - val_accuracy: 0.1094
# Epoch 26/100
# 40/40 [==============================] - 39s 977ms/step - loss: 2.0948 - accuracy: 0.4516 - val_loss: 5.8822 - val_accuracy: 0.1035
# Epoch 27/100
# 40/40 [==============================] - 39s 975ms/step - loss: 2.0987 - accuracy: 0.4530 - val_loss: 5.5069 - val_accuracy: 0.1007
# Epoch 28/100
# 40/40 [==============================] - 39s 976ms/step - loss: 2.0237 - accuracy: 0.4640 - val_loss: 6.1087 - val_accuracy: 0.0996
# Epoch 29/100
# 40/40 [==============================] - 39s 973ms/step - loss: 1.9627 - accuracy: 0.4799 - val_loss: 5.8314 - val_accuracy: 0.1068
# Epoch 30/100
# 40/40 [==============================] - 39s 977ms/step - loss: 1.8773 - accuracy: 0.4948 - val_loss: 6.2447 - val_accuracy: 0.1208
# Epoch 31/100
# 40/40 [==============================] - 39s 977ms/step - loss: 1.8607 - accuracy: 0.5008 - val_loss: 6.1895 - val_accuracy: 0.1015
# Epoch 32/100
# 40/40 [==============================] - 39s 972ms/step - loss: 1.7926 - accuracy: 0.5136 - val_loss: 6.1731 - val_accuracy: 0.1055
# Epoch 33/100
# 40/40 [==============================] - 39s 981ms/step - loss: 1.7257 - accuracy: 0.5309 - val_loss: 6.1621 - val_accuracy: 0.1029
# Epoch 34/100
# 40/40 [==============================] - 40s 983ms/step - loss: 1.6746 - accuracy: 0.5350 - val_loss: 6.2251 - val_accuracy: 0.1041
# Epoch 35/100
# 40/40 [==============================] - 39s 974ms/step - loss: 1.6422 - accuracy: 0.5461 - val_loss: 6.2108 - val_accuracy: 0.1015
# Epoch 36/100
# 40/40 [==============================] - 39s 973ms/step - loss: 1.5797 - accuracy: 0.5632 - val_loss: 6.7965 - val_accuracy: 0.1076
# Epoch 37/100
# 40/40 [==============================] - 39s 974ms/step - loss: 1.5399 - accuracy: 0.5698 - val_loss: 6.5155 - val_accuracy: 0.1121
# Epoch 38/100
# 40/40 [==============================] - 39s 973ms/step - loss: 1.5222 - accuracy: 0.5748 - val_loss: 6.7277 - val_accuracy: 0.1037
# Epoch 39/100
# 40/40 [==============================] - 39s 975ms/step - loss: 1.4805 - accuracy: 0.5905 - val_loss: 6.7823 - val_accuracy: 0.1064
# Epoch 40/100
# 40/40 [==============================] - 39s 971ms/step - loss: 1.4501 - accuracy: 0.5888 - val_loss: 7.0172 - val_accuracy: 0.1082
# Epoch 41/100
# 40/40 [==============================] - 39s 981ms/step - loss: 1.4025 - accuracy: 0.6040 - val_loss: 6.8544 - val_accuracy: 0.1161
# Epoch 42/100
# 40/40 [==============================] - 39s 970ms/step - loss: 1.3565 - accuracy: 0.6195 - val_loss: 6.9847 - val_accuracy: 0.1123
# Epoch 43/100
# 40/40 [==============================] - 39s 966ms/step - loss: 1.3072 - accuracy: 0.6291 - val_loss: 7.4122 - val_accuracy: 0.0998
# Epoch 44/100
# 40/40 [==============================] - 39s 968ms/step - loss: 1.2894 - accuracy: 0.6288 - val_loss: 7.3435 - val_accuracy: 0.1135
# Epoch 45/100
# 40/40 [==============================] - 39s 969ms/step - loss: 1.2805 - accuracy: 0.6361 - val_loss: 6.9598 - val_accuracy: 0.1223
# Epoch 46/100
# 40/40 [==============================] - 39s 961ms/step - loss: 1.2269 - accuracy: 0.6446 - val_loss: 7.4429 - val_accuracy: 0.1204
# Epoch 47/100
# 40/40 [==============================] - 39s 963ms/step - loss: 1.1941 - accuracy: 0.6565 - val_loss: 7.5392 - val_accuracy: 0.1159
# Epoch 48/100
# 40/40 [==============================] - 39s 966ms/step - loss: 1.1305 - accuracy: 0.6724 - val_loss: 8.4735 - val_accuracy: 0.1204
# Epoch 49/100
# 40/40 [==============================] - 39s 964ms/step - loss: 1.1692 - accuracy: 0.6621 - val_loss: 7.1321 - val_accuracy: 0.1296
# Epoch 50/100
# 40/40 [==============================] - 39s 963ms/step - loss: 1.1138 - accuracy: 0.6766 - val_loss: 6.8681 - val_accuracy: 0.1241
# Epoch 51/100
# 40/40 [==============================] - 39s 959ms/step - loss: 1.0851 - accuracy: 0.6825 - val_loss: 7.5627 - val_accuracy: 0.1174
# Epoch 52/100
# 40/40 [==============================] - 39s 965ms/step - loss: 1.0332 - accuracy: 0.6979 - val_loss: 8.0477 - val_accuracy: 0.1129
# Epoch 53/100
# 40/40 [==============================] - 39s 962ms/step - loss: 1.0259 - accuracy: 0.6977 - val_loss: 7.8442 - val_accuracy: 0.1186
# Epoch 54/100
# 40/40 [==============================] - 39s 964ms/step - loss: 1.0370 - accuracy: 0.6973 - val_loss: 8.1342 - val_accuracy: 0.1231
# Epoch 55/100
# 40/40 [==============================] - 39s 963ms/step - loss: 1.0125 - accuracy: 0.7025 - val_loss: 7.8700 - val_accuracy: 0.1170
# Epoch 56/100
# 40/40 [==============================] - 39s 965ms/step - loss: 0.9793 - accuracy: 0.7162 - val_loss: 8.5407 - val_accuracy: 0.1157
# Epoch 57/100
# 40/40 [==============================] - 39s 964ms/step - loss: 0.9729 - accuracy: 0.7116 - val_loss: 8.0148 - val_accuracy: 0.1186
# Epoch 58/100
# 40/40 [==============================] - 39s 962ms/step - loss: 0.9583 - accuracy: 0.7180 - val_loss: 8.2899 - val_accuracy: 0.1110
# Epoch 59/100
# 40/40 [==============================] - 39s 959ms/step - loss: 0.9394 - accuracy: 0.7212 - val_loss: 8.7780 - val_accuracy: 0.1133
# Epoch 60/100
# 40/40 [==============================] - 39s 964ms/step - loss: 0.9176 - accuracy: 0.7273 - val_loss: 8.7344 - val_accuracy: 0.1167
# Epoch 61/100
# 40/40 [==============================] - 39s 966ms/step - loss: 0.9344 - accuracy: 0.7264 - val_loss: 8.1695 - val_accuracy: 0.1265
# Epoch 62/100
# 40/40 [==============================] - 39s 963ms/step - loss: 0.8807 - accuracy: 0.7426 - val_loss: 8.5228 - val_accuracy: 0.1114
# Epoch 63/100
# 40/40 [==============================] - 39s 960ms/step - loss: 0.9026 - accuracy: 0.7336 - val_loss: 8.5994 - val_accuracy: 0.1119
# Epoch 64/100
# 40/40 [==============================] - 39s 964ms/step - loss: 0.9285 - accuracy: 0.7291 - val_loss: 9.2198 - val_accuracy: 0.1155
# Epoch 65/100
# 40/40 [==============================] - 39s 969ms/step - loss: 0.8777 - accuracy: 0.7422 - val_loss: 8.4930 - val_accuracy: 0.1096
# Epoch 66/100
# 40/40 [==============================] - 39s 965ms/step - loss: 0.8374 - accuracy: 0.7524 - val_loss: 9.0041 - val_accuracy: 0.1188
# Epoch 67/100
# 40/40 [==============================] - 39s 962ms/step - loss: 0.8348 - accuracy: 0.7531 - val_loss: 8.5067 - val_accuracy: 0.1167
# Epoch 68/100
# 40/40 [==============================] - 39s 967ms/step - loss: 0.7999 - accuracy: 0.7593 - val_loss: 8.6483 - val_accuracy: 0.1049
# Epoch 69/100
# 40/40 [==============================] - 39s 963ms/step - loss: 0.7645 - accuracy: 0.7695 - val_loss: 8.7440 - val_accuracy: 0.1249
# Epoch 70/100
# 40/40 [==============================] - 39s 966ms/step - loss: 0.7965 - accuracy: 0.7632 - val_loss: 8.9723 - val_accuracy: 0.1163
# Epoch 71/100
# 40/40 [==============================] - 39s 963ms/step - loss: 0.7729 - accuracy: 0.7713 - val_loss: 8.8853 - val_accuracy: 0.1076
# Epoch 72/100
# 40/40 [==============================] - 39s 962ms/step - loss: 0.7658 - accuracy: 0.7710 - val_loss: 8.9542 - val_accuracy: 0.1267
# Epoch 73/100
# 40/40 [==============================] - 39s 967ms/step - loss: 0.7516 - accuracy: 0.7775 - val_loss: 9.1733 - val_accuracy: 0.1155
# Epoch 74/100
# 40/40 [==============================] - 39s 960ms/step - loss: 0.7763 - accuracy: 0.7676 - val_loss: 8.6219 - val_accuracy: 0.1139
# Epoch 75/100
# 40/40 [==============================] - 39s 966ms/step - loss: 0.7826 - accuracy: 0.7638 - val_loss: 9.7380 - val_accuracy: 0.1176
# Epoch 76/100
# 40/40 [==============================] - 39s 965ms/step - loss: 0.7879 - accuracy: 0.7652 - val_loss: 9.1489 - val_accuracy: 0.1184
# Epoch 77/100
# 40/40 [==============================] - 39s 965ms/step - loss: 0.7541 - accuracy: 0.7748 - val_loss: 8.4027 - val_accuracy: 0.1363
# Epoch 78/100
# 40/40 [==============================] - 39s 965ms/step - loss: 0.7204 - accuracy: 0.7829 - val_loss: 9.3246 - val_accuracy: 0.1233
# Epoch 79/100
# 40/40 [==============================] - 39s 963ms/step - loss: 0.7123 - accuracy: 0.7830 - val_loss: 9.2167 - val_accuracy: 0.1208
# Epoch 80/100
# 40/40 [==============================] - 39s 962ms/step - loss: 0.7013 - accuracy: 0.7904 - val_loss: 9.8189 - val_accuracy: 0.1167
# Epoch 81/100
# 40/40 [==============================] - 39s 966ms/step - loss: 0.6707 - accuracy: 0.7996 - val_loss: 9.3445 - val_accuracy: 0.1214
# Epoch 82/100
# 40/40 [==============================] - 39s 963ms/step - loss: 0.7437 - accuracy: 0.7784 - val_loss: 9.3466 - val_accuracy: 0.1208
# Epoch 83/100
# 40/40 [==============================] - 39s 966ms/step - loss: 0.7114 - accuracy: 0.7880 - val_loss: 10.2728 - val_accuracy: 0.1237
# Epoch 84/100
# 40/40 [==============================] - 39s 963ms/step - loss: 0.6881 - accuracy: 0.7929 - val_loss: 8.6600 - val_accuracy: 0.1184
# Epoch 85/100
# 40/40 [==============================] - 39s 968ms/step - loss: 0.7347 - accuracy: 0.7828 - val_loss: 8.4454 - val_accuracy: 0.1227
# Epoch 86/100
# 40/40 [==============================] - 39s 966ms/step - loss: 0.6658 - accuracy: 0.7991 - val_loss: 9.2920 - val_accuracy: 0.1220
# Epoch 87/100
# 40/40 [==============================] - 39s 967ms/step - loss: 0.6110 - accuracy: 0.8167 - val_loss: 9.7925 - val_accuracy: 0.1271
# Epoch 88/100
# 40/40 [==============================] - 39s 966ms/step - loss: 0.6587 - accuracy: 0.8009 - val_loss: 9.8978 - val_accuracy: 0.1196
# Epoch 89/100
# 40/40 [==============================] - 39s 968ms/step - loss: 0.6612 - accuracy: 0.8004 - val_loss: 9.3364 - val_accuracy: 0.1375
# Epoch 90/100
# 40/40 [==============================] - 39s 964ms/step - loss: 0.6569 - accuracy: 0.8028 - val_loss: 9.5801 - val_accuracy: 0.1253
# Epoch 91/100
# 40/40 [==============================] - 39s 960ms/step - loss: 0.6468 - accuracy: 0.8079 - val_loss: 8.6728 - val_accuracy: 0.1269
# Epoch 92/100
# 40/40 [==============================] - 39s 963ms/step - loss: 0.6905 - accuracy: 0.7948 - val_loss: 8.6655 - val_accuracy: 0.1192
# Epoch 93/100
# 40/40 [==============================] - 39s 961ms/step - loss: 0.6306 - accuracy: 0.8111 - val_loss: 9.1104 - val_accuracy: 0.1265
# Epoch 94/100
# 40/40 [==============================] - 39s 966ms/step - loss: 0.6421 - accuracy: 0.8064 - val_loss: 9.6067 - val_accuracy: 0.1172
# Epoch 95/100
# 40/40 [==============================] - 39s 963ms/step - loss: 0.6976 - accuracy: 0.7896 - val_loss: 9.5038 - val_accuracy: 0.1218
# Epoch 96/100
# 40/40 [==============================] - 39s 959ms/step - loss: 0.6353 - accuracy: 0.8104 - val_loss: 9.3043 - val_accuracy: 0.1210
# Epoch 97/100
# 40/40 [==============================] - 39s 965ms/step - loss: 0.6755 - accuracy: 0.7997 - val_loss: 9.1370 - val_accuracy: 0.1218
# Epoch 98/100
# 40/40 [==============================] - 39s 965ms/step - loss: 0.6402 - accuracy: 0.8074 - val_loss: 9.5556 - val_accuracy: 0.1231
# Epoch 99/100
# 40/40 [==============================] - 39s 963ms/step - loss: 0.6008 - accuracy: 0.8202 - val_loss: 9.3830 - val_accuracy: 0.1277
# Epoch 100/100
# 40/40 [==============================] - 39s 964ms/step - loss: 0.5916 - accuracy: 0.8209 - val_loss: 9.6240 - val_accuracy: 0.1223
